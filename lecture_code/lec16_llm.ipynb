# %% [markdown]
# <div style="max-width:66ch;">
#
# # Lecture notes - Large language model (LLM)
#
# This is the lecture note for **transfer learning**.
#
# <p class = "alert alert-info" role="alert"><b>Note</b> that this lecture note gives a brief introduction to LLM. I encourage you to read further about large language models. </p>
#
# Read more:
#
# - [EDEN AI](https://app.edenai.run/bricks/default)
#
# </div>

# %% [markdown]
# <div style="max-width:66ch;">
#
# ## Setup
#
# Very important to use .env to hide your API key and have a gitignore which ignores .env files so that it doesn't get tracked in your git and pushed to github.
#
# - you get the API key through registering in Eden AI
#
# </div>

# %%
import json
import requests
from dotenv import load_dotenv
from pathlib import Path
import os

load_dotenv(Path()/"../.env")
api_key = os.getenv("EDEN_API")

# chatbot_global_action = """
# Agera som om du vore anställd marknadsförare inom en skola. Denna skola
# har utbildningar inom tech/IT och handelsrelaterade ämnen såsom inköp,
# paralegal och supply chain. Målgruppen är potentiella studenter.
# """

headers = {"Authorization": f"Bearer {api_key}"}


def chat(prompt, provider="perplexityai", model="mixtral-8x7b-instruct"):
    headers = {"Authorization": f"Bearer {api_key}"}

    url = "https://api.edenai.run/v2/text/chat"
    payload = {
        # "providers": "openai",
        # "model": "gpt-4",
        "providers": provider,
        "model": model,
        "text": prompt,
        "chatbot_global_action": "Act as an assistant",
        "previous_history": [], # add history to give the model memory
        "temperature": 0.5, # temperature to control creativity
        "max_tokens": 500,
        "fallback_providers": "perplexityai",
    }

    response = requests.post(url, json=payload, headers=headers)

    result = json.loads(response.text)
    return result[provider]["generated_text"]

# %%
with open("../data/programmering-med-ai-kompetens.txt", "r") as file:
    raw_text = file.read()

print(raw_text)
# Out:
# Vill du vara med och skapa framtidens system och applikationer med AI? Då är yrkesrollen som mjukvaruutvecklare med AI kompetens och utbildningen Objektorienterad programmering med AI-kompetens rätt för dig. Som mjukvaruutvecklare skapar och skriver du program som skall utföra specifika uppgifter. Efter utbildningen kan du jobba som t ex mjukvaruutvecklare inom C#, Python och med AI-applikationer. Kort om utbildningen Göteborg
#  2024-05-19  2024-08-26  Mars/April – boka din plats här!
# ...

# %%
summary_opa = chat(
    f"""kan du sammanfatta den här texten i max en paragraf 
    {raw_text}

    Formattera svaret enligt nedan exempel
    '''
    Texten beskriver AI och utbildning ...

    Några viktiga delar är:
    - punkt 1 
    - punkt 2
    - ... 

    '''

    """,
    provider="openai",
    model="gpt-3.5-turbo",
)

print(summary_opa)
# Out:
# Texten beskriver rollen som mjukvaruutvecklare med AI-kompetens och utbildningen i objektorienterad programmering med AI-kompetens som riktar sig mot att skapa framtidens system och applikationer med AI. Mjukvaruutvecklare skapar och skriver programkod för att instruera datorer att utföra specifika uppgifter, med fokus på C#, Python och AI-applikationer. Utbildningen betonar vikten av att förvärva kunskaper inom objektorienterad programmering och tillämpa dem inom området för artificiell intelligens. Viktiga delar inkluderar behovet av specialiserade utvecklare, arbetsuppgifter som testning och dokumentation, samt betydelsen av att kunna samarbeta i team för att uppnå projektens mål.

# %%
learn_opa = chat(
    f"'''{raw_text}'''\n\nVad får man lära sig här? Beskriv kort i punktformat. Lägg också till radbrytningar mellan varje punkt.",
    provider="openai",
    model="gpt-3.5-turbo",
)
print(learn_opa)
# Out:
# - Objektorienterad programmering med fokus på C#
# - Användning av Python för AI-applikationer
# - Testning och säkerställande av kodens funktionalitet
# - Skrivande och underhåll av kod- och systemdokumentation
# - Samarbeten i team med andra utvecklare och intressenter
# - Strukturering av kod genom objekt för innovativa lösningar
# - Användning av agil projektmetodik som Scrum och Kanban
# - Konstruktion av webbbackend-system med återanvändbara komponenter
# - Utveckling av webbfrontend med HTML, CSS och JavaScript
# - Skapande av maskininlärningsmodeller för verkliga problem
# - Modellering och användning av relationsdatabaser med SQL
# - Självständig konstruktion och implementering av program
# - Presentationsteknik, projektledning och examensarbete inom systemutveckling
# - Praktisk erfarenhet genom 14-20 veckors praktikperiod hos företag
# - Anpassning av utbildningen efter arbetslivets behov och kompetensutveckling
# ...

# %%
contacts = chat(
    f"""Vilka ska man kontakta om man är intresserad av utbildningen? '''{raw_text}''' 
    
    Formatera i en lista på kontakter
    """,
    provider="openai",
    model="gpt-3.5-turbo",
)

# %%
print(contacts)
# Out:
# Här är en lista på kontakter för att få mer information om utbildningen:
#
# 1. Magdalena Vidoevska
#    E-post: magdalena.vidoevska@nbi-handelsakademin.se
#    Telefon: +46 31-704 67 16
#
# 2. Sandra Kellander
#    E-post: sandra.kellander@nbi-handelsakademin.se
#    Telefon: +46 31-704 67 19
#
# 3. Magdalena Fagerlind
#    E-post: magdalena.fagerlind@nbi-handelsakademin.se
#
# Du kan även kontakta dem via generell e-post:
# E-post: hej@nbi-handelsakademin.se

# %%
contacts_table= chat(
    f"""Vilka ska man kontakta om man är intresserad av utbildningen? '''{raw_text}''' 
    
    Formatera i en markdowntabell med kolumnerna: Kontakt, Mail, Telefon
    """,
    provider="openai",
    model="gpt-3.5-turbo",
)
contacts_table
# Out:
# '| Kontakt                     | Mail                                    | Telefon        |\n|-----------------------------|-----------------------------------------|----------------|\n| Magdalena Vidoevska        | magdalena.vidoevska@nbi-handelsakademin.se | +46 31-704 67 16 |\n| Sandra Kellander            | sandra.kellander@nbi-handelsakademin.se   | +46 31-704 67 19 |\n| Magdalena Fagerlind         | magdalena.fagerlind@nbi-handelsakademin.se |                |\n| Allmän support              | hej@nbi-handelsakademin.se                 |                |'

# %%
print(contacts_table)
# Out:
# | Kontakt                     | Mail                                    | Telefon        |
# |-----------------------------|-----------------------------------------|----------------|
# | Magdalena Vidoevska        | magdalena.vidoevska@nbi-handelsakademin.se | +46 31-704 67 16 |
# | Sandra Kellander            | sandra.kellander@nbi-handelsakademin.se   | +46 31-704 67 19 |
# | Magdalena Fagerlind         | magdalena.fagerlind@nbi-handelsakademin.se |                |
# | Allmän support              | hej@nbi-handelsakademin.se                 |                |

# %% [markdown]
# ## Some other tests
#
#
# ### Dataframe?
# - can we get dataframe from this markdown?

# %%
contacts_df= chat(
    f"""Vilka ska man kontakta om man är intresserad av utbildningen? '''{raw_text}''' 
    
    Formatera i en pandas dataframe med kolumnerna: Kontakt, Mail, Telefon
    """,
    provider="openai",
    model="gpt-3.5-turbo",
)

contacts_df
# Out:
# '| Kontakt              | Mail                                    | Telefon        |\n|----------------------|-----------------------------------------|----------------|\n| Magdalena Vidoevska  | magdalena.vidoevska@nbi-handelsakademin.se | +46 31-704 67 16 |\n| Sandra Kellander     | sandra.kellander@nbi-handelsakademin.se  | +46 31-704 67 19 |\n| Magdalena Fagerlind  | magdalena.fagerlind@nbi-handelsakademin.se | +46 31-704 67 19 |\n| Allmän kontakt       | hej@nbi-handelsakademin.se               | N/A            |'

# %%
print(
    chat(
        "show me an example of python code to create a pandas dataframe from a markdown table",
        provider="openai",
        model="gpt-3.5-turbo",
    )
)
# Out:
# Here is an example of Python code that creates a Pandas DataFrame from a markdown table:
#
# ```python
# import pandas as pd
# from io import StringIO
#
# # Markdown table
# markdown_table = """
# | Name | Age | City    |
# |------|-----|---------|
# | Alice| 25  | New York|
# | Bob  | 30  | Chicago |
# | Eve  | 28  | Boston  |
# """
#
# # Create a Pandas DataFrame from the markdown table
# df = pd.read_csv(StringIO(markdown_table), sep="|", skipinitialspace=True, skiprows=1, engine='python')
#
# print(df)
# ```
#
# This code reads the markdown table as a CSV using `pd.read_csv` and then prints the resulting Pandas DataFrame.

# %%
print(contacts_df)
# Out:
# | Kontakt              | Mail                                    | Telefon        |
# |----------------------|-----------------------------------------|----------------|
# | Magdalena Vidoevska  | magdalena.vidoevska@nbi-handelsakademin.se | +46 31-704 67 16 |
# | Sandra Kellander     | sandra.kellander@nbi-handelsakademin.se  | +46 31-704 67 19 |
# | Magdalena Fagerlind  | magdalena.fagerlind@nbi-handelsakademin.se | +46 31-704 67 19 |
# | Allmän kontakt       | hej@nbi-handelsakademin.se               | N/A            |

# %%
import pandas as pd
from io import StringIO

# nah okay - didn't went so well but maybe with other prompting
df = pd.read_csv(
    StringIO(contacts_df), sep="|", skipinitialspace=True, skiprows=1, engine="python"
)
df
# Out:
#    Unnamed: 0 ----------------------  \
# 0         NaN  Magdalena Vidoevska
# 1         NaN  Sandra Kellander
# 2         NaN  Magdalena Fagerlind
# 3         NaN  Allmän kontakt
#
#      -----------------------------------------   ----------------  Unnamed: 4
# 0  magdalena.vidoevska@nbi-handelsakademin.se   +46 31-704 67 16          NaN
# 1    sandra.kellander@nbi-handelsakademin.se    +46 31-704 67 19          NaN
# 2  magdalena.fagerlind@nbi-handelsakademin.se   +46 31-704 67 19          NaN
# 3    hej@nbi-handelsakademin.se                   N/A                     NaN

# %% [markdown]
# ### FAQ
#
# Can we use it for FAQ, using answers from an existing FAQ?

# %%
from utils.scraper import FaqScraper

faq = FaqScraper()
faq

# %%
faq_list = faq.faq
faq_list
# Out:
# ['Vilka utbildningar startar till hösten?',
#  'Använd filterfunktionen på startsidan för att se vilka utbildningar som startar.',
#  'När öppnar ansökan?',
#  'Vi öppnar ansökan i december för utbildningar som är inplanerade sedan tidigare. I januari/februari öppnar vi ansökan för nya utbildningsstarter. Anmäl ditt intresse så får du mail från oss om nya utbildningsstarter.',
#  'När är sista ansökningsdag?',
#  'Sista dag för att skicka in ansökan är den 19 maj. Vi granskar ansökningarna kontinuerligt och skickar en påminnelse om du behöver komplettera din ansökan.',
#  '\xa0',
#  'Vad innebär Sen anmälan?',
#  'Det innebär att kan man bli antagen i mån av plats, efter det att samtliga som sökt i tid har bedömts och fått chansen.',
#  'När är sista dag för att komplettera ansökan?',
# ...

# %%
print("\n\n".join(faq_list))
# Out:
# Vilka utbildningar startar till hösten?
#
# Använd filterfunktionen på startsidan för att se vilka utbildningar som startar.
#
# När öppnar ansökan?
#
# Vi öppnar ansökan i december för utbildningar som är inplanerade sedan tidigare. I januari/februari öppnar vi ansökan för nya utbildningsstarter. Anmäl ditt intresse så får du mail från oss om nya utbildningsstarter.
#
# När är sista ansökningsdag?
#
# Sista dag för att skicka in ansökan är den 19 maj. Vi granskar ansökningarna kontinuerligt och skickar en påminnelse om du behöver komplettera din ansökan.
#
#
#
# Vad innebär Sen anmälan?
#
# Det innebär att kan man bli antagen i mån av plats, efter det att samtliga som sökt i tid har bedömts och fått chansen.
#
# När är sista dag för att komplettera ansökan?
#
# ...

# %%
questions = [text for text in faq_list if "?" in text]
questions
# Out:
# ['Vilka utbildningar startar till hösten?',
#  'När öppnar ansökan?',
#  'När är sista ansökningsdag?',
#  'Vad innebär Sen anmälan?',
#  'När är sista dag för att komplettera ansökan?',
#  'Kan man ansöka till flera utbildningar samtidigt?',
#  'Måste jag skriva ett personligt brev i min ansökan och berätta mer om mig själv?',
#  'Måste jag skicka med undertecknade intyg från arbetsgivare?',
#  'Mina betyg finns på antagning.se, kan ni hämta där?',
#  'Hur många sökande brukar det vara?',
#  'Kan man söka studiemedel hos CSN?',
#  'Hur blir man behörig?',
#  'Vad händer om du inte är behörig?',
#  'Vad är skillnaden mellan "behörighet" och "urval"?',
#  'Jag har betyg från kurser på högskola/universitet eller annan YH-utbildning. Kan jag tillgodoräkna mig det?',
#  'Måste man ha arbetslivserfarenhet?',
#  'Vad är Urvalsprov?',
#  'Jag har bokat in mig på urvalsprov men fått förhinder. Kan jag boka ett annat tillfälle?',
#  'Har ni intervjuer?',
#  'Måste jag göra urvalsprov?',
# ...

# %%
chat(
    f"""Från denna lista med frågor 
    '''
    {questions}
    '''

    Ta fram frågan som är mest lik denna fråga:

    '''
    Hur mycket kostar det att plugga era utbildningar?
    '''


    """,
    provider="openai",
    model="gpt-3.5-turbo",
)

# now from this we could extract the answer 
# also to be more robust we should prompt it to answer in certain format to get repeatability
# Out:
# 'Frågan som är mest lik "Hur mycket kostar det att plugga era utbildningar?" från listan du gav är "Kostar det något?"'

# %% [markdown]
# <div style="max-width:66ch;">
#
# ## Summary
#
# In this lecture we've covered LLM using Eden AI, which gives an easy way to access APIs for variety of models. It gives a small budget for simpler testing and experimentations, which is a good starting point for learning and explorations.
#
# </div>

# %% [markdown]
# <div style="background-color: #FFF; color: #212121; border-radius: 1px; width:22ch; box-shadow: rgba(0, 0, 0, 0.16) 0px 1px 4px; display: flex; justify-content: center; align-items: center;">
# <div style="padding: 1.5em 0; width: 70%;">
#     <h2 style="font-size: 1.2rem;">Kokchun Giang</h2>
#     <a href="https://www.linkedin.com/in/kokchungiang/" target="_blank" style="display: flex; align-items: center; gap: .4em; color:#0A66C2;">
#         <img src="https://content.linkedin.com/content/dam/me/business/en-us/amp/brand-site/v2/bg/LI-Bug.svg.original.svg" width="20">
#         LinkedIn profile
#     </a>
#     <a href="https://github.com/kokchun/Portfolio-Kokchun-Giang" target="_blank" style="display: flex; align-items: center; gap: .4em; margin: 1em 0; color:#0A66C2;">
#         <img src="https://github.githubassets.com/images/modules/logos_page/GitHub-Mark.png" width="20">
#         Github portfolio
#     </a>
#     <span>AIgineer AB</span>
# <div>
# </div>
