# %%
import pandas 
import sklearn 
import matplotlib.pyplot as plt 
import numpy as np

# %%
x = np.linspace(-5,5)
y = x**2

plt.plot(x,y)

# %%
from tensorflow import keras
data = keras.datasets.mnist.load_data()
len(data)
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# 2

# %%
len(data[0])
# Out:
# 2

# %%
data[0][0].shape
# Out:
# (60000, 28, 28)

# %%
data[0][0][0].shape
# Out:
# (28, 28)

# %%
data[0][0][0].min(), data[0][0][0].max()
# Out:
# (0, 255)

# %%
import matplotlib.pyplot as plt 

plt.imshow(data[0][0][1000], cmap="gray")
