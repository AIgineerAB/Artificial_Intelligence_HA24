# %%
# !pwd
# Out:
# /kaggle/working

# %%
# !ls
# !ls -al
# !ls -al .virtual_documents/
# Out:
# total 12
# drwxr-xr-x 3 root root 4096 May  8 07:21 .
# drwxr-xr-x 5 root root 4096 May  8 07:20 ..
# drwxr-xr-x 2 root root 4096 May  8 07:21 .virtual_documents
# total 8
# drwxr-xr-x 2 root root 4096 May  8 07:21 .
# drwxr-xr-x 3 root root 4096 May  8 07:21 ..

# %%
# !ls /
# Out:
# '=2023.0.1'	 etc		       lib32    opt		 sbin   var
#  bin		 home		       lib64    proc		 srv
#  boot		 install_packages.sh   libx32   root		 sys
#  dev		 kaggle		       media    run		 tmp
#  entrypoint.sh	 lib		       mnt      run_jupyter.sh	 usr

# %%
# !ls ..
# Out:
# input  lib  working

# %%
# !ls ../lib
# !ls ../lib/kaggle
# Out:
# kaggle
# gcp.py

# %%
# !ls ../input
# Out:
# train-data

# %%
# !ls ../input/train-data/
# Out:
# dog.10121.jpg  dog.10597.jpg  dog.11073.jpg  dog.11549.jpg  dog.12025.jpg
# dog.10122.jpg  dog.10598.jpg  dog.11074.jpg  dog.11550.jpg  dog.12026.jpg
# dog.10123.jpg  dog.10599.jpg  dog.11075.jpg  dog.11551.jpg  dog.12027.jpg
# dog.10124.jpg  dog.10600.jpg  dog.11076.jpg  dog.11552.jpg  dog.12028.jpg
# dog.10125.jpg  dog.10601.jpg  dog.11077.jpg  dog.11553.jpg  dog.12029.jpg
# dog.10126.jpg  dog.10602.jpg  dog.11078.jpg  dog.11554.jpg  dog.12030.jpg
# dog.10127.jpg  dog.10603.jpg  dog.11079.jpg  dog.11555.jpg  dog.12031.jpg
# dog.10128.jpg  dog.10604.jpg  dog.11080.jpg  dog.11556.jpg  dog.12032.jpg
# dog.10129.jpg  dog.10605.jpg  dog.11081.jpg  dog.11557.jpg  dog.12033.jpg
# dog.10130.jpg  dog.10606.jpg  dog.11082.jpg  dog.11558.jpg  dog.12034.jpg
# dog.10131.jpg  dog.10607.jpg  dog.11083.jpg  dog.11559.jpg  dog.12035.jpg
# dog.10132.jpg  dog.10608.jpg  dog.11084.jpg  dog.11560.jpg  dog.12036.jpg
# dog.10133.jpg  dog.10609.jpg  dog.11085.jpg  dog.11561.jpg  dog.12037.jpg
# ...

# %%
# !ls /kaggle/input
# Out:
# train-data

# %%
import matplotlib.pyplot as plt 
from pathlib import Path
import os 

train_path = "<local_path>"
# val_path ...
# test_path ...

if "KAGGLE_KERNEL_RUN_TYPE" in os.environ:
    train_path = Path().absolute().parent / "input" / "train-data"

train_path
# Out:
# PosixPath('/kaggle/input/train-data')

# %%
sample_image = plt.imread(train_path / "dog.12497.jpg")
sample_image.shape
# Out:
# (375, 499, 3)

# %%
plt.imshow(sample_image)

# %%
import fuzzyfuzzy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 import fuzzyfuzzy
#
# ModuleNotFoundError: No module named 'fuzzyfuzzy'

# %%
# !pip install fuzzywuzzy

# %%
import fuzzywuzzy
